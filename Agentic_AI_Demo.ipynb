# %% [markdown]
# # Agentic AI: From Chatbots to Agents
# **Presented by:** Sharad Rajore | **Organization:** Zensar Technologies
#
# ---
#
# ### 🎯 Learning Objectives
# 1. **Witness the Limitations:** See where a raw LLM fails (Math & Real-time data).
# 2. **Build Tools:** Create "Hands" for the AI using Python functions.
# 3. **The ReAct Loop:** Observe the *Thought -> Action -> Observation* cycle in real-time.
#
# ### 🛠️ Prerequisites
# - Python 3.10+
# - LangChain installed (`pip install langchain langchain-openai`)
# - OpenAI API Key (or similar)

# %%
# 1. Setup Environment
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Part 1: The "Brain in a Jar" (LLM Limitations)
# First, let's look at a standard LLM. It is powerful but isolated. It cannot access the outside world and often hallucinates on complex math.

# %%
from langchain_openai import ChatOpenAI

# Initialize the "Brain" (LLM)
llm = ChatOpenAI(model="gpt-4o", temperature=0)

# TEST 1: The Math Trap
# LLMs predict the next word, they don't calculate. 
# For large numbers, they often guess.
query = "What is 49,823 multiplied by 19,283?"

response = llm.invoke(query)
print(f"User: {query}")
print(f"LLM Answer: {response.content}")

# Reality Check: 49823 * 19283 = 960,736,909
# Check if the LLM got it right (It often fails or is slightly off without a tool).
# Out:
# User: What is 49,823 multiplied by 19,283?
# LLM Answer: 49,823 multiplied by 19,283 equals 960,418,309.

# %% [markdown]
# ## Part 2: Giving the Brain "Hands" (Defining Tools)
# To fix this, we don't train the model more. We give it a **Tool**.
# In LangChain, a tool is just a Python function with a `@tool` decorator.

# %%
from langchain_core.tools import tool

# 1. Define the Calculator Tool
@tool
def multiply(a: int, b: int) -> int:
    """Multiplies two integers and returns the result."""
    return a * b

# 2. Define a "Mock" Search Tool (Simulating Real-time data)
@tool
def get_stock_price(ticker: str) -> str:
    """Returns the current stock price for a given ticker symbol. 
    Use 'ZENSAR' for Zensar Technologies, 'GOOGL' for Google."""
    # In a real agent, this would call Yahoo Finance API
    ticker_upper = ticker.upper().strip()
    if "ZENSAR" in ticker_upper:
        return "750.00 INR"
    elif "GOOGL" in ticker_upper or "GOOGLE" in ticker_upper:
        return "175.00 USD"
    else:
        return f"Unknown Ticker: {ticker}"

# List of tools available to our Agent
tools = [multiply, get_stock_price]

print("Tools Created: Calculator (Hands) & Stock Search (Eyes)")
# Out:
# Tools Created: Calculator (Hands) & Stock Search (Eyes)

# %% [markdown]
# ## Part 3: The Agent (ReAct Loop)
# Now we bind the tools to the LLM. The LLM will now act as a router:
# 1. **Thought:** Do I know the answer? No.
# 2. **Action:** Pick the right tool.
# 3. **Observation:** Get the output.
# 4. **Final Answer:** Summarize for the user.

# %%
from langchain.agents import create_agent

# Create a ReAct agent using the modern LangChain API
# debug=True enables verbose output showing the Thought -> Action -> Observation loop
agent_executor = create_agent(llm, tools, debug=True)

print("Agent created successfully with ReAct capabilities!")
# Out:
# Agent created successfully with ReAct capabilities!

# %% [markdown]
# ## Part 4: Agent in Action
# Let's ask the exact same math question, plus a question about Zensar's stock.

# %%
print("--- SCENARIO 1: MATH ---")
result1 = agent_executor.invoke({"messages": [("user", "What is 49,823 multiplied by 19,283?")]})
print(f"\nFinal Answer: {result1['messages'][-1].content}")

print("\n\n--- SCENARIO 2: REAL-TIME DATA ---")
result2 = agent_executor.invoke({"messages": [("user", "What is the current stock price of Zensar?")]})
print(f"\nFinal Answer: {result2['messages'][-1].content}")
# Out:
# --- SCENARIO 1: MATH ---
# [values] {'messages': [HumanMessage(content='What is 49,823 multiplied by 19,283?', additional_kwargs={}, response_metadata={}, id='b5d0a54e-1f10-4967-ad4f-f2be772576c1')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 109, 'total_tokens': 128, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q1lQaAtqOZBBEYDpxrf2glhBPp', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-5b85-7f51-9451-b8a35166e662-0', tool_calls=[{'name': 'multiply', 'args': {'a': 49823, 'b': 19283}, 'id': 'call_gNHK5MXR9E1ru7paSZXrXHR7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 19, 'total_tokens': 128, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='What is 49,823 multiplied by 19,283?', additional_kwargs={}, response_metadata={}, id='b5d0a54e-1f10-4967-ad4f-f2be772576c1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 109, 'total_tokens': 128, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q1lQaAtqOZBBEYDpxrf2glhBPp', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-5b85-7f51-9451-b8a35166e662-0', tool_calls=[{'name': 'multiply', 'args': {'a': 49823, 'b': 19283}, 'id': 'call_gNHK5MXR9E1ru7paSZXrXHR7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 19, 'total_tokens': 128, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='960736909', name='multiply', id='e57a2840-b87e-4402-9ef8-dd18997d920f', tool_call_id='call_gNHK5MXR9E1ru7paSZXrXHR7')]}}
# [values] {'messages': [HumanMessage(content='What is 49,823 multiplied by 19,283?', additional_kwargs={}, response_metadata={}, id='b5d0a54e-1f10-4967-ad4f-f2be772576c1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 109, 'total_tokens': 128, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q1lQaAtqOZBBEYDpxrf2glhBPp', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-5b85-7f51-9451-b8a35166e662-0', tool_calls=[{'name': 'multiply', 'args': {'a': 49823, 'b': 19283}, 'id': 'call_gNHK5MXR9E1ru7paSZXrXHR7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 19, 'total_tokens': 128, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='960736909', name='multiply', id='e57a2840-b87e-4402-9ef8-dd18997d920f', tool_call_id='call_gNHK5MXR9E1ru7paSZXrXHR7')]}
# [updates] {'model': {'messages': [AIMessage(content='49,823 multiplied by 19,283 is 960,736,909.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 138, 'total_tokens': 156, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q2x3ug1vFwAnaQhIzH4NutkmEg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019df7b5-6507-72c3-8ee4-bb3ee7eadfe4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 138, 'output_tokens': 18, 'total_tokens': 156, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='What is 49,823 multiplied by 19,283?', additional_kwargs={}, response_metadata={}, id='b5d0a54e-1f10-4967-ad4f-f2be772576c1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 109, 'total_tokens': 128, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q1lQaAtqOZBBEYDpxrf2glhBPp', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-5b85-7f51-9451-b8a35166e662-0', tool_calls=[{'name': 'multiply', 'args': {'a': 49823, 'b': 19283}, 'id': 'call_gNHK5MXR9E1ru7paSZXrXHR7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 19, 'total_tokens': 128, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='960736909', name='multiply', id='e57a2840-b87e-4402-9ef8-dd18997d920f', tool_call_id='call_gNHK5MXR9E1ru7paSZXrXHR7'), AIMessage(content='49,823 multiplied by 19,283 is 960,736,909.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 138, 'total_tokens': 156, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q2x3ug1vFwAnaQhIzH4NutkmEg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019df7b5-6507-72c3-8ee4-bb3ee7eadfe4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 138, 'output_tokens': 18, 'total_tokens': 156, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
#
# Final Answer: 49,823 multiplied by 19,283 is 960,736,909.
#
#
# --- SCENARIO 2: REAL-TIME DATA ---
# [values] {'messages': [HumanMessage(content='What is the current stock price of Zensar?', additional_kwargs={}, response_metadata={}, id='8e90c154-ed4d-4a77-8e24-f09ea362d7c7')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 107, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q3OpKPAyHSRplj2M2RR2cj4R1o', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-69b1-7a83-9419-38008cf256b0-0', tool_calls=[{'name': 'get_stock_price', 'args': {'ticker': 'ZENSAR'}, 'id': 'call_xarBYQz3PSjSvcq8EcyNr5jh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 17, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='What is the current stock price of Zensar?', additional_kwargs={}, response_metadata={}, id='8e90c154-ed4d-4a77-8e24-f09ea362d7c7'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 107, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q3OpKPAyHSRplj2M2RR2cj4R1o', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-69b1-7a83-9419-38008cf256b0-0', tool_calls=[{'name': 'get_stock_price', 'args': {'ticker': 'ZENSAR'}, 'id': 'call_xarBYQz3PSjSvcq8EcyNr5jh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 17, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='750.00 INR', name='get_stock_price', id='6b39d426-447b-44e3-9691-d6db08067a19', tool_call_id='call_xarBYQz3PSjSvcq8EcyNr5jh')]}}
# [values] {'messages': [HumanMessage(content='What is the current stock price of Zensar?', additional_kwargs={}, response_metadata={}, id='8e90c154-ed4d-4a77-8e24-f09ea362d7c7'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 107, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q3OpKPAyHSRplj2M2RR2cj4R1o', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-69b1-7a83-9419-38008cf256b0-0', tool_calls=[{'name': 'get_stock_price', 'args': {'ticker': 'ZENSAR'}, 'id': 'call_xarBYQz3PSjSvcq8EcyNr5jh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 17, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='750.00 INR', name='get_stock_price', id='6b39d426-447b-44e3-9691-d6db08067a19', tool_call_id='call_xarBYQz3PSjSvcq8EcyNr5jh')]}
# [updates] {'model': {'messages': [AIMessage(content='The current stock price of Zensar Technologies is 750.00 INR.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 137, 'total_tokens': 154, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q5Eh3UmYnJ6vf0UaitY9UYR54x', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019df7b5-6e4e-7fa2-bff2-7f630362cc35-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 137, 'output_tokens': 17, 'total_tokens': 154, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='What is the current stock price of Zensar?', additional_kwargs={}, response_metadata={}, id='8e90c154-ed4d-4a77-8e24-f09ea362d7c7'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 107, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q3OpKPAyHSRplj2M2RR2cj4R1o', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-69b1-7a83-9419-38008cf256b0-0', tool_calls=[{'name': 'get_stock_price', 'args': {'ticker': 'ZENSAR'}, 'id': 'call_xarBYQz3PSjSvcq8EcyNr5jh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 17, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='750.00 INR', name='get_stock_price', id='6b39d426-447b-44e3-9691-d6db08067a19', tool_call_id='call_xarBYQz3PSjSvcq8EcyNr5jh'), AIMessage(content='The current stock price of Zensar Technologies is 750.00 INR.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 137, 'total_tokens': 154, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q5Eh3UmYnJ6vf0UaitY9UYR54x', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019df7b5-6e4e-7fa2-bff2-7f630362cc35-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 137, 'output_tokens': 17, 'total_tokens': 154, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
#
# Final Answer: The current stock price of Zensar Technologies is 750.00 INR.

# %%
print("\n\n--- SCENARIO 3: REAL-TIME DATA ---")
result2 = agent_executor.invoke({"messages": [("user", "What is the current stock price of Zensar? and What is 49,823 multiplied by 19,283? and what is the capital of France?")]})
print(f"\nFinal Answer: {result2['messages'][-1].content}")
# Out:
# --- SCENARIO 3: REAL-TIME DATA ---
# [values] {'messages': [HumanMessage(content='What is the current stock price of Zensar? and What is 49,823 multiplied by 19,283? and what is the capital of France?', additional_kwargs={}, response_metadata={}, id='c580e672-4f93-45b4-b85e-aefc80ca9028')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 129, 'total_tokens': 181, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q6357RWKwuVOo3pt6VWAkkOYcH', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-73fd-7a93-9b27-8d85c2eb13a6-0', tool_calls=[{'name': 'get_stock_price', 'args': {'ticker': 'ZENSAR'}, 'id': 'call_0Tul0zELzwTuexhz7cfQv9Mg', 'type': 'tool_call'}, {'name': 'multiply', 'args': {'a': 49823, 'b': 19283}, 'id': 'call_GYYebhqlPJ3RGPoGsezaYrr1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 129, 'output_tokens': 52, 'total_tokens': 181, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='What is the current stock price of Zensar? and What is 49,823 multiplied by 19,283? and what is the capital of France?', additional_kwargs={}, response_metadata={}, id='c580e672-4f93-45b4-b85e-aefc80ca9028'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 129, 'total_tokens': 181, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q6357RWKwuVOo3pt6VWAkkOYcH', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-73fd-7a93-9b27-8d85c2eb13a6-0', tool_calls=[{'name': 'get_stock_price', 'args': {'ticker': 'ZENSAR'}, 'id': 'call_0Tul0zELzwTuexhz7cfQv9Mg', 'type': 'tool_call'}, {'name': 'multiply', 'args': {'a': 49823, 'b': 19283}, 'id': 'call_GYYebhqlPJ3RGPoGsezaYrr1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 129, 'output_tokens': 52, 'total_tokens': 181, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='750.00 INR', name='get_stock_price', id='30233f8e-da81-44f9-8e0b-e5aefa7a137b', tool_call_id='call_0Tul0zELzwTuexhz7cfQv9Mg')]}}
# [updates] {'tools': {'messages': [ToolMessage(content='960736909', name='multiply', id='78bb8f83-9b0e-4378-8010-fb1f1469171b', tool_call_id='call_GYYebhqlPJ3RGPoGsezaYrr1')]}}
# [values] {'messages': [HumanMessage(content='What is the current stock price of Zensar? and What is 49,823 multiplied by 19,283? and what is the capital of France?', additional_kwargs={}, response_metadata={}, id='c580e672-4f93-45b4-b85e-aefc80ca9028'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 129, 'total_tokens': 181, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q6357RWKwuVOo3pt6VWAkkOYcH', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-73fd-7a93-9b27-8d85c2eb13a6-0', tool_calls=[{'name': 'get_stock_price', 'args': {'ticker': 'ZENSAR'}, 'id': 'call_0Tul0zELzwTuexhz7cfQv9Mg', 'type': 'tool_call'}, {'name': 'multiply', 'args': {'a': 49823, 'b': 19283}, 'id': 'call_GYYebhqlPJ3RGPoGsezaYrr1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 129, 'output_tokens': 52, 'total_tokens': 181, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='750.00 INR', name='get_stock_price', id='30233f8e-da81-44f9-8e0b-e5aefa7a137b', tool_call_id='call_0Tul0zELzwTuexhz7cfQv9Mg'), ToolMessage(content='960736909', name='multiply', id='78bb8f83-9b0e-4378-8010-fb1f1469171b', tool_call_id='call_GYYebhqlPJ3RGPoGsezaYrr1')]}
# [updates] {'model': {'messages': [AIMessage(content='- The current stock price of Zensar Technologies is 750.00 INR.\n- The result of multiplying 49,823 by 19,283 is 960,736,909.\n- The capital of France is Paris.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 202, 'total_tokens': 250, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q7xg1Bj0dl7q8n6xKrK2oVID2T', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019df7b5-7983-7710-b959-c907d430a96e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 202, 'output_tokens': 48, 'total_tokens': 250, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='What is the current stock price of Zensar? and What is 49,823 multiplied by 19,283? and what is the capital of France?', additional_kwargs={}, response_metadata={}, id='c580e672-4f93-45b4-b85e-aefc80ca9028'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 129, 'total_tokens': 181, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q6357RWKwuVOo3pt6VWAkkOYcH', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019df7b5-73fd-7a93-9b27-8d85c2eb13a6-0', tool_calls=[{'name': 'get_stock_price', 'args': {'ticker': 'ZENSAR'}, 'id': 'call_0Tul0zELzwTuexhz7cfQv9Mg', 'type': 'tool_call'}, {'name': 'multiply', 'args': {'a': 49823, 'b': 19283}, 'id': 'call_GYYebhqlPJ3RGPoGsezaYrr1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 129, 'output_tokens': 52, 'total_tokens': 181, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='750.00 INR', name='get_stock_price', id='30233f8e-da81-44f9-8e0b-e5aefa7a137b', tool_call_id='call_0Tul0zELzwTuexhz7cfQv9Mg'), ToolMessage(content='960736909', name='multiply', id='78bb8f83-9b0e-4378-8010-fb1f1469171b', tool_call_id='call_GYYebhqlPJ3RGPoGsezaYrr1'), AIMessage(content='- The current stock price of Zensar Technologies is 750.00 INR.\n- The result of multiplying 49,823 by 19,283 is 960,736,909.\n- The capital of France is Paris.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 202, 'total_tokens': 250, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_246dab3317', 'id': 'chatcmpl-Dc7Q7xg1Bj0dl7q8n6xKrK2oVID2T', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019df7b5-7983-7710-b959-c907d430a96e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 202, 'output_tokens': 48, 'total_tokens': 250, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
#
# Final Answer: - The current stock price of Zensar Technologies is 750.00 INR.
# - The result of multiplying 49,823 by 19,283 is 960,736,909.
# - The capital of France is Paris.

# %% [markdown]
# ### 🧠 What just happened?
# 1. **Math:** Instead of guessing, you should see the agent say `Invoking: multiply`. It used the calculator.
# 2. **Stock:** Instead of saying "I don't know", it said `Invoking: get_stock_price`.
#
# **This is the shift from Generative AI (guessing) to Agentic AI (executing).**
